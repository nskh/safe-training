# %% [markdown]
# # NN Reachablity Demo

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# TODO get interactive plotting working in jupyterlab
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy

from interval import interval, inf, imath

from safe_train import *

# %% [markdown]
# ## Demo

# %%
x, y = generate_data()
plt.figure()
plt.scatter(x, y)
plt.show()

# %%
model, history = train_single_node_nn(x, y)
plot_loss(history)
# Out:
# 2023-04-03 10:52:06.650203: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-04-03 10:52:06.650379: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-04-03 10:52:06.717960: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-04-03 10:52:06.768097: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:52:06.780121: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Metal device set to: Apple M1 Pro
# 2023-04-03 10:52:07.396935: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-04-03 10:52:08.319452: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
plot_predictions(model, x, y, [0, 60], [0, 60])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 2023-04-03 10:52:25.660576: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
# neural network values
y_predict = model.predict(x)
# scipy values
popt, _ = scipy.optimize.curve_fit(lambda x, b0, b1: b0 + b1 * x, x, y)
y_scipy = x * popt[1] + popt[0]
# Out:
# 1/1 [==============================] - 0s 10ms/step

# %%
input_interval = interval[20, 40]
output_interval = propagate_interval(input_interval, model)
plot_intervals(input_interval, output_interval, x, y, y_predict, y_scipy)
